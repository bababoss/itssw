# %% [markdown]
# #  Demostration Midas project

# %%
import requests,json
import pprint as pp
headers = {'Content-type': 'application/json'}
model_api={"scenesegmentation":"http://35.199.173.101:8990/api/v1/scenesegmentation",
           "objectdetection":"http://35.199.173.101:8990/api/v1/objectdetection",
           "nonspeech_label":"http://35.199.173.101:8990/api/v1/media/nonspeech/label",
           "nonspeech_separation":"http://35.199.173.101:8990/api/v1/media/nonspeech/separation",
           "face_detection":"http://35.199.173.101:8990/api/v1/face/detection",
           
          }
result_api={"model_result":"http://35.199.173.101:8990/api/v1/modelresult?video_id=163",
           "allmediametadata":"http://35.199.173.101:8990/api/v1/allmediametadata",
           "model_search":"http://35.199.173.101:8990/api/v1/modeldetail?model_type=seg",
           }

# %% [markdown]
# # 1. Scene_segmentation model

# %% [markdown]
# ## 1.1 Example scene_segmentation

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv"}
r=requests.post(model_api["scenesegmentation"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'id': 85,
#               'scene000': {'end_f_time': '00:00:05:21',
#                            'end_frame': 141,
#                            'end_time': 5.880875,
#                            'start_f_time': '00:00:00:00',
#                            'start_frame': 0,
#                            'start_time': 0.0,
#                            'total_frames': 141},
#               'scene001': {'end_f_time': '00:00:09:18',
#                            'end_frame': 234,
#                            'end_time': 9.759749999999999,
#                            'start_f_time': '00:00:05:21',
#                            'start_frame': 141,
#                            'start_time': 5.880875,
#                            'total_frames': 93},
#               'scene002': {'end_f_time': '00:00:13:21',
#                            'end_frame': 333,
#                            'end_time': 13.888874999999999,
#                            'start_f_time': '00:00:09:18',
# ...

# %% [markdown]
# ## 1.2 Example scene_segmentation

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv"}
r=requests.post(model_api["scenesegmentation"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'id': 86,
#               'scene000': {'end_f_time': '00:00:02:21',
#                            'end_frame': 69,
#                            'end_time': 2.8779247202441502,
#                            'start_f_time': '00:00:00:00',
#                            'start_frame': 0,
#                            'start_time': 0.0,
#                            'total_frames': 69},
#               'scene001': {'end_f_time': '00:00:13:11',
#                            'end_frame': 323,
#                            'end_time': 13.47202441505595,
#                            'start_f_time': '00:00:02:21',
#                            'start_frame': 69,
#                            'start_time': 2.8779247202441502,
#                            'total_frames': 254},
#               'scene002': {'end_f_time': '00:00:15:23',
#                            'end_frame': 383,
#                            'end_time': 15.974567650050863,
# ...

# %% [markdown]
# # 2 .Object detection model

# %% [markdown]
# ## 2.1 Exapmle object detection model

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv"}
r=requests.post(model_api["objectdetection"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'scene000': {'detections': [{'frame_no': 150,
#                                            'objects': [{'class': 'traffic '
#                                                                  'light',
#                                                         'height': 993,
#                                                         'score': '0.6036424',
#                                                         'width': 700,
#                                                         'x_position': 435,
#                                                         'y_position': 860},
#                                                        {'class': 'car',
#                                                         'height': 190,
#                                                         'score': '0.4605792',
#                                                         'width': 286,
#                                                         'x_position': 0,
# ...

# %% [markdown]
# ## 2.2 Exapmle object detection model

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv"}
r=requests.post(model_api["objectdetection"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'scene000': {'detections': [{'frame_no': 70,
#                                            'objects': [{'class': 'person',
#                                                         'height': 1280,
#                                                         'score': '0.9963385',
#                                                         'width': 718,
#                                                         'x_position': 25,
#                                                         'y_position': 578},
#                                                        {'class': 'bed',
#                                                         'height': 940,
#                                                         'score': '0.71012264',
#                                                         'width': 706,
#                                                         'x_position': 306,
#                                                         'y_position': 7},
# ...

# %% [markdown]
# # 3. Non speech labelling

# %% [markdown]
# ## 3.1  Example Non speech labelling

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv"}
r=requests.post(model_api["nonspeech_label"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# ('{"success":true,"response":{"segments":[{"end_time":6.47,"start_time":2.47,"label":"Background '
#  'Music"},{"end_time":21.31,"start_time":15.95,"label":"Background '
#  'Music"}],"filename":"d832029c9c8375b36133.wav","sampling":16000}}')

# %% [markdown]
# ## 3.2 Example  Non speech labelling

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/a9143e62db1b4e8b9ab5f74f3615acc9.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/a9143e62db1b4e8b9ab5f74f3615acc9.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/a9143e62db1b4e8b9ab5f74f3615acc9.mkv"}
r=requests.post(model_api["nonspeech_label"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'filename': 'e2d02fb6dd59b09621d4.wav',
#               'sampling': 16000,
#               'segments': [{'end_time': 6.88,
#                             'label': 'Background Music',
#                             'start_time': 4.2},
#                            {'end_time': 32.7,
#                             'label': 'Background Music',
#                             'start_time': 7.19},
#                            {'end_time': 36.96,
#                             'label': 'Background Music',
#                             'start_time': 33.16},
#                            {'end_time': 41.83,
#                             'label': 'Wind',
#                             'start_time': 37.62},
#                            {'end_time': 55.19,
#                             'label': 'honking',
#                             'start_time': 42.44},
#                            {'end_time': 88.58,
#                             'label': 'Wind',
# ...

# %% [markdown]
# ## 3.3 Example  Non speech labelling

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/6e4d448780dc4a5d8c6144aced359c49.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/6e4d448780dc4a5d8c6144aced359c49.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/6e4d448780dc4a5d8c6144aced359c49.mkv"}
r=requests.post(model_api["nonspeech_label"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': "(<class 'json.decoder.JSONDecodeError'>, "
#              "JSONDecodeError('Expecting value: line 1 column 1 (char 0)',), "
#              '<traceback object at 0x7f43d8d338c8>)',
#  'success': False}

# %% [markdown]
# #  4. Speech and Non speech separation model

# %% [markdown]
# ## 4.1 Exapmle Speech and Non speech separation

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/582ff783e3234035b720cd613f25c5c6.mkv"}
r=requests.post(model_api["nonspeech_separation"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'filename': 'd832029c9c8375b36133.wav',
#               'non-speech': [{'end_time': 6.47, 'start_time': 2.47},
#                              {'end_time': 21.31, 'start_time': 15.95}],
#               'sampling': 16000,
#               'speech': [{'end_time': 2.47, 'start_time': 1.82},
#                          {'end_time': 6.93, 'start_time': 6.47},
#                          {'end_time': 9.41, 'start_time': 8.37},
#                          {'end_time': 11.34, 'start_time': 10.04},
#                          {'end_time': 12.85, 'start_time': 12.49},
#                          {'end_time': 13.22, 'start_time': 12.86},
#                          {'end_time': 15.95, 'start_time': 14.84},
#                          {'end_time': 22.7, 'start_time': 21.31},
#                          {'end_time': 22.91, 'start_time': 22.71},
#                          {'end_time': 23.81, 'start_time': 23.39},
#                          {'end_time': 24.36, 'start_time': 23.83}]},
# ...

# %% [markdown]
# ## 4.2 Exapmle Speech and Non speech separation

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/a9143e62db1b4e8b9ab5f74f3615acc9.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/a9143e62db1b4e8b9ab5f74f3615acc9.mkv"}
r=requests.post(model_api["nonspeech_separation"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())

# %% [markdown]
# # Demo 1 face detection model

# %%
# %%HTML
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/c44fc9617bc74ead947583e28378494e.mkv" type="video/mp4">
# </video>
# Out:
# <video width="480" height="320" controls>
#   <source src="http://35.199.173.101:8990/media/uploaded_media/c44fc9617bc74ead947583e28378494e.mkv" type="video/mp4">
# </video>

# %%
payload={"media_file": "http://35.199.173.101:8990/media/uploaded_media/8ac5a844e9c04e2ba07422132979edab.mkv"}
r=requests.post(model_api["face_detection"],data=json.dumps(payload),headers=headers)
pp.pprint(r.json())
# Out:
# {'response': {'scene000': {'detections': [{'face': [],
#                                            'frame_no': 142,
#                                            'time_code': '00:00:05:142'},
#                                           {'face': [],
#                                            'frame_no': 143,
#                                            'time_code': '00:00:05:143'},
#                                           {'face': [],
#                                            'frame_no': 144,
#                                            'time_code': '00:00:06:144'},
#                                           {'face': [],
#                                            'frame_no': 145,
#                                            'time_code': '00:00:06:145'},
#                                           {'face': [],
#                                            'frame_no': 146,
#                                            'time_code': '00:00:06:146'},
# ...

# %% [markdown]
# # Result meta data api

# %% [markdown]
# ### 1. API for letest uploaded video and audio

# %%
pp.pprint(requests.get(result_api["allmediametadata"]).json())
# Out:
# {'response': [{'audio_file': '/media/audio_output/ef0135cf575040a8b7af582853e353eb.wav',
#                'id': 224,
#                'media_file': '/media/uploaded_media/ef0135cf575040a8b7af582853e353eb.mkv'},
#               {'audio_file': '/media/audio_output/acaacf2e387a4040bd5df8f315e35478.wav',
#                'id': 223,
#                'media_file': '/media/uploaded_media/acaacf2e387a4040bd5df8f315e35478.mkv'},
#               {'audio_file': '/media/audio_output/1ce33a95049346e7ab087960a5bdbb3c.wav',
#                'id': 222,
#                'media_file': '/media/uploaded_media/1ce33a95049346e7ab087960a5bdbb3c.mkv'},
#               {'audio_file': None,
#                'id': 221,
#                'media_file': '/media/uploaded_media/79b3491cb1e04d84bee4a176cd7686e8.mkv'},
#               {'audio_file': None,
#                'id': 220,
#                'media_file': '/media/uploaded_media/ab9d90f40f4d4a8ab3ec6a3fb0a716cb.mkv'},
#               {'audio_file': None,
# ...

# %% [markdown]
# ### 2. all model result using video_id

# %%
pp.pprint(requests.get(result_api["model_result"]).json())
# Out:
# {'response': {'audio_url': 'http://35.199.173.101:8990/media/audio_output/c44fc9617bc74ead947583e28378494e.wav',
#               'result': [{'model_type': 'scene_segmentation',
#                           'result': "{'scene026': {'start_time': "
#                                     "132.46795523906408, 'start_f_time': "
#                                     "'00:02:12:11', 'total_frames': 859, "
#                                     "'end_time': 168.29603255340794, "
#                                     "'start_frame': 3176, 'end_f_time': "
#                                     "'00:02:48:07', 'end_frame': 4035}, "
#                                     "'scene022': {'start_time': "
#                                     "115.617497456765, 'start_f_time': "
#                                     "'00:01:55:14', 'total_frames': 60, "
#                                     "'end_time': 118.12004069175991, "
#                                     "'start_frame': 2772, 'end_f_time': "
# ...
